# %%
import pandas as pd
import psycopg2
import sqlalchemy as sl

# %%
username = 'KhokMaksym'
password = '1234543'
database = 'Lab_2_DB'

engine = sl.create_engine(f'postgresql+psycopg2://{username}:{password}@localhost/{database}')

# %%
query_1_select = '''
SELECT * FROM Customers
'''

query_2_select = '''
SELECT * FROM Orders
'''

query_3_select = '''
SELECT * FROM Products
'''

query_4_select = '''
SELECT * FROM Cities
'''

query_5_select = '''
SELECT * FROM OrderItems
'''

# %%
df_1 = pd.read_sql(query_1_select, con=engine)
df_1
# Out:
#        cust_id                                          full_name  \
# 0       110099  Savala, Marlo                                 ...
# 1        21070  Cuyler, Cleo                                  ...
# 2        62618  Hetherington, Kanisha                         ...
# 3        90333  Groves, Katharine                             ...
# 4        90334  Arceo, Amalia                                 ...
# ...        ...                                                ...
# 64243    62616  Gullette, Keven                               ...
# 64244   100849  Bohan, Awilda                                 ...
# 64245    73489  Penney, Roscoe                                ...
# 64246    90332  Reiley, Tonia                                 ...
# 64247    62617  Farren, Coleman                               ...
#
#                                                city_name  \
# 0      Bethel                                        ...
# ...

# %%
df_2 = pd.read_sql(query_2_select, con=engine)
df_2
# Out:
#          order_id                                             status  cust_id
# 0       100354678  received                                      ...    60124
# 1       100363940  canceled                                      ...    62428
# 2       100354680  complete                                      ...    60124
# 3       100354922  complete                                      ...    16488
# 4       100367357  received                                      ...    60124
# ...           ...                                                ...      ...
# 201707  100562365  paid                                          ...   115323
# 201708  100562376  cod                                           ...   115324
# 201709  100562383  cod                                           ...   115325
# 201710  100562384  cod                                           ...   115325
# 201711  100562386  processing                                    ...   115326
#
# [201712 rows x 3 columns]

# %%
df_3 = pd.read_sql(query_3_select, con=engine)
df_3
# Out:
#                                                      sku  \
# 0      FOX5AFAB6254343D                              ...
# 1      SNO5AE6ABE2EAFDA                              ...
# 2      CLE5B07E029D2EF6                              ...
# 3      CLE5B07E02542484                              ...
# 4      MEFDEA5B03D53E1D43D-L                         ...
# ...                                                  ...
# 47924  MATLDN5A9F7B53E1939                           ...
# 47925  MATLDN5A65B779DB6A3                           ...
# 47926  COMLDN5AB2096951D0E                           ...
# 47927  COMLDN5AB2096D37A5A                           ...
# 47928  MATLDN5A65B7797A455                           ...
#
#                                                 category  price
# 0      Superstore                                    ...    7.3
# 1      Superstore                                    ...    3.0
# 2      Superstore                                    ...   14.3
# ...

# %%
df_4 = pd.read_sql(query_4_select, con=engine)
df_4
# Out:
#                                                city_name    zip  city_state
# 0      Vinson                                        ...  73571  OK
# 1      Brevard                                       ...  28712  NC
# 2      Eakly                                         ...  73033  OK
# 3      Berthoud                                      ...  80513  CO
# 4      Graham                                        ...  32042  FL
# ...                                                  ...    ...         ...
# 15887  North Prairie                                 ...  53153  WI
# 15888  Aaronsburg                                    ...  16820  PA
# 15889  Pueblo Of Acoma                               ...  87034  NM
# 15890  Power                                         ...  59468  MT
# 15891  Dell City                                     ...  79837  TX
#
# [15892 rows x 3 columns]

# %%
df_5 = pd.read_sql(query_5_select, con=engine)
df_5
# Out:
#         item_id   order_id                                                sku  \
# 0        716083  100437221  MEFWIN5A01AA2C40ED2                           ...
# 1        722441  100440708  WOFMUN5A0ACC3394AC8                           ...
# 2        722442  100440708  SADHED59D489D77313F                           ...
# 3        722443  100440708  HALNAD59E0AD7728A6D                           ...
# 4        732772  100446605  KABSTI5A044B8FA6712                           ...
# ...         ...        ...                                                ...
# 286382   667507  100408843  APPORI5A02E10B6581D                           ...
# 286383   667548  100408868  APPORI5A02E10B6581D                           ...
# 286384   667516  100408851  WOFMUN5A0ACC3852748-9                         ...
# 286385   716081  100437221  SADHED59D489CEAD013                           ...
# 286386   716082  100437221  HALNAD59E0AD7728A6D                           ...
#
#         qty_ordered  total
# ...

# %%
df_1.to_csv('customers.csv', index=False)
df_2.to_csv('orders.csv', index=False)
df_3.to_csv('products.csv', index=False)
df_4.to_csv('cities.csv', index=False)
df_5.to_csv('orderitems.csv', index=False)
